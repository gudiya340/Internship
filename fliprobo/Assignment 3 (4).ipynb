# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\yashika\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: trio~=0.17 in c:\users\yashika\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\yashika\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\yashika\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\yashika\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: idna in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\yashika\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\yashika\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\yashika\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\yashika\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\yashika\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
value = input("Enter your item: ")
# Out:
# Enter your item: guitar

# %%
search_tags = driver.find_element(By.XPATH,'//div[@class="nav-search-field "]//input')
search_tags.send_keys(value)
search_button = driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]//span')
search_button.click()
time.sleep(3)

# %%
producturls = []
brand_name= []
product_name =[]
price = []
retexchange = []
exp_delivery = []
avail = []

# %%
start = 0
end = 3
for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url[0:10]:
        producturls.append(i.get_attribute("href"))
        
    next_button= driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()
    time.sleep(3)

# %%
for url in producturls[:20]:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand_tags = driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span')
        brand_name.append(brand_tags.text)
    except NoSuchElementException:
        brand_name.append('-')

    try:
        product_tags = driver.find_element(By.XPATH,'//*[@id="productTitle"]')
        product_name.append(product_tags.text)
    except NoSuchElementException:
        product_name.append('-')


    try:
        price_tags = driver.find_element(By.XPATH,'//*[@id="corePriceDisplay_desktop_feature_div"]/div[1]/span[2]/span[2]/span[2]')
        price.append(price_tags.text)
    except NoSuchElementException:
        price.append('-')

    try:
        exchange_tags = driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]/span/div[2]/a')
        retexchange.append(exchange_tags.text)
    except NoSuchElementException:
        retexchange.append('-')

    try:
        delivery_tags = driver.find_element(By.XPATH,'//*[@id="mir-layout-DELIVERY_BLOCK-slot-PRIMARY_DELIVERY_MESSAGE_LARGE"]/span/span')
        exp_delivery.append(delivery_tags.text)
    except NoSuchElementException:
        exp_delivery.append('-')
        
    try:
        avail_tags = driver.find_element(By.XPATH,'//*[@id="availability"]/span')
        avail.append(avail_tags.text)
    except NoSuchElementException:
        avail.append('-')

# %%
print (len(brand_name), len(product_name), len(price), len(retexchange), len(exp_delivery), len(avail))
# Out:
# 20 20 20 20 20 20

# %%
import pandas as pd
df = pd.DataFrame({'BRAND':brand_name, 'Product Name': product_name,'Price': price, 'Return/Exchange': retexchange, 'Expected Delivery': exp_delivery, 'Availibility': avail})
df
# Out:
#                  BRAND                                       Product Name  \
# 0              Kadence  Kadence Slowhand Premium Jumbo Semi Acoustic G...
# 1              Kadence  Kadence Frontier Jumbo Semi Acoustic Guitar Wi...
# 2              Kadence  Kadence Frontier guitar with Online Guitar lea...
# 3               Intern  INTERN 40 inches Acoustic Guitar with Pick-up ...
# 4               JUAREZ  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
# 5               Intern  Intern INT-38C Right hand Acoustic Guitar Kit,...
# 6               YAMAHA  Yamaha F280 Acoustic Rosewood Guitar (Natural,...
# 7              Kadence  Kadence Frontier Jumbo Semi Acoustic Guitar Wi...
# 8              Kadence  Kadence Slowhand Premium Jumbo Semi Acoustic G...
# 9              Kadence  Kadence Frontier guitar with Online Guitar lea...
# 10          Guitar Bro  GUITAR BRO - COMBO (Blue Acoustic Guitar for B...
# 11              JUAREZ  Juârez Lindenwood Acoustic Guitar, 38 Inches C...
# 12                Cort  Cort AF515CE 6-String Electro Acoustic Guitar ...
# 13              JUAREZ  Juarez JRZ-ST01 6-String Electric Guitar, Righ...
# 14              Intern  Intern INT-38C Lindenwood Acoustic Guitar Kit ...
# 15              YAMAHA  Yamaha F280 Acoustic Guitar, Natural With Baja...
# 16              YAMAHA  Yamaha FS80C 25 Incheses sprucewood The Ultima...
# 17              Henrix  Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...
# 18  ORANGEWOOD GUITARS  ORANGEWOOD OLIVER JR. MAHOGANY MINI GRAND CONC...
# 19              JUAREZ  Juarez Acoustic Lindenwood Guitar, 38 Inches C...
#
#      Price     Return/Exchange Expected Delivery          Availibility
# 0   11,999  7 days Replacement  Tuesday, 7 March              In stock
# 1    6,499  7 days Replacement  Tuesday, 7 March              In stock
# 2    4,999  7 days Replacement   Sunday, 5 March              In stock
# 3    4,999  7 days Replacement   Sunday, 5 March              In stock
# 4    1,999  7 days Replacement   Sunday, 5 March              In stock
# 5    2,299  7 days Replacement   Sunday, 5 March              In stock
# 6    7,200  7 days Replacement   Sunday, 5 March              In stock
# 7    6,499  7 days Replacement  Tuesday, 7 March              In stock
# 8   11,999  7 days Replacement  Tuesday, 7 March              In stock
# 9    4,999  7 days Replacement   Sunday, 5 March              In stock
# 10   8,999  7 days Replacement      March 7 - 10              In stock
# 11   2,790  7 days Replacement   Sunday, 5 March              In stock
# 12  12,700  7 days Replacement   Sunday, 5 March  Only 1 left in stock
# 13   5,749  7 days Replacement   Sunday, 5 March              In stock
# 14   2,399  7 days Replacement   Sunday, 5 March              In stock
# 15   7,899  7 days Replacement   Sunday, 5 March              In stock
# 16   8,839  7 days Replacement   Monday, 6 March              In stock
# 17   2,849  7 days Replacement   Sunday, 5 March              In stock
# 18       -  7 days Replacement   Monday, 6 March  Only 1 left in stock
# 19   2,499  7 days Replacement   Sunday, 5 March              In stock

# %% [markdown]
# Question 3

# %%
driver.get("https://images.google.com/")

# %%
value = ['guitar','cars and machine learning','cake','fruits']

# %%
search_img = driver.find_element(By.CLASS_NAME,"gLFyf")
search_img.send_keys(value)


search_button = driver.find_element(By.CLASS_NAME,"Tg7LZd")
search_button.click()
time.sleep(3)

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

# %%
img_urls =[]
img_data = []

# %%
for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)

# %%
for i in range(len(img_urls)):
    if i >10:
        break
    print("Downloading {0} of {1} images ".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Yashika\Documents\images"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %% [markdown]
# Question 4

# %%
driver.get("https://www.flipkart.com/")

# %%
smartphone =  input("Enter the smartphone name: ")
# Out:
# Enter the smartphone name: oneplus

# %%
time.sleep(5)
search_tag = driver.find_element(By.CLASS_NAME,"_3704LK")
search_tag.send_keys(smartphone)
search_button = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search_button.click()
time.sleep(3)

# %%
purls = []
brand_name = []
smartphone_name = []
colour = []
RAM = []
ROM = []
pcamera = []
scamera = []
display = []
battery = []
price = []

# %%
url = driver.find_elements(By.CLASS_NAME,"s1Q9rs")
for i in url:
    purls.append(i.get_attribute("href"))

# %%
print(len(purls))
# Out:
# 40

# %%
for url in purls[0:2]:
    driver.get(url)
    read_more = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/button')
    read_more.click()
    
    time.sleep(20)
    try:
        brand_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[2]/div/div[1]/h1/span')
        brand_name.append(brand_tags.text)
    except NoSuchElementException:
        brand_name.append('-')

    try:
        phone_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/div[1]/div[1]/table/tbody/tr[3]/td[2]/ul/li')
        smartphone_name.append(phone_tags.text)
    except NoSuchElementException:
        smartphone_name.append('-')


    try:
        price_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[2]/div/div[3]/div[1]/div/div[1]')
        price.append(price_tags.text)
    except NoSuchElementException:
        price.append('-')

    
    try:
        display_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[6]/div[1]/div/div[2]/ul/li[2]')
        display.append(display_tags.text)
    except NoSuchElementException:
        display.append('-')
        
    try:
        pcam_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr/td[2]/ul/li')
        pcamera.append(pcam_tags.text)
    except NoSuchElementException:
        pcamera.append('-')
        
    try:
        scam_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[6]/table/tbody/tr[6]/td[2]/ul/li')
        scamera.append(scam_tags.text)
    except NoSuchElementException:
        scamera.append('-')
       
    try:
        ram_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]/ul/li')
        RAM.append(ram_tags.text)
    except NoSuchElementException:
        RAM.append('-')
        
    try:
        rom_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li')
        ROM.append(rom_tags.text)
    except NoSuchElementException:
        ROM.append('-')
        
    try:
        battery_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/div[1]/div[7]/table/tbody/tr/td[2]/ul/li')
        battery.append(battery_tags.text)
    except NoSuchElementException:
        battery.append('-')
    
    try:
        colour_tags = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/div[1]/div[1]/table/tbody/tr[4]/td[2]/ul/li')
        colour.append(colour_tags.text)
    except NoSuchElementException:
        colour.append('-')

# %%
print (len(brand_name), len(smartphone_name), len(price), len(colour), len(display), len(pcamera), len(scamera), len(RAM), len(ROM), len(battery))
# Out:
# 8 8 8 8 8 8 8 8 8 8

# %%
import pandas as pd
df = pd.DataFrame({'BRAND':brand_name, 'Smartphone Name': smartphone_name,'Price': price, 'RAM': RAM, 'Storage/ROM': ROM, 'colour': colour, 'battery': battery, 'display': display, 'Primary Camera': pcamera, 'Secondary Camera': scamera})
df
# Out:
#                                                BRAND    Smartphone Name  \
# 0  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  Nord CE 2 Lite 5G
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...  Nord CE 2 Lite 5G
# 2  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...  Nord CE 2 Lite 5G
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  Nord CE 2 Lite 5G
# 4  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...  Nord CE 2 Lite 5G
# 5  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...  Nord CE 2 Lite 5G
# 6  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  Nord CE 2 Lite 5G
# 7  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...  Nord CE 2 Lite 5G
#
#      Price   RAM Storage/ROM      colour   battery  \
# 0  ₹19,820  6 GB      128 GB  Black Dusk  5000 mAh
# 1  ₹19,989  6 GB      128 GB   Blue Tide  5000 mAh
# 2  ₹19,948  6 GB      128 GB   Blue Tide  5000 mAh
# 3  ₹19,820  6 GB      128 GB  Black Dusk  5000 mAh
# 4  ₹19,989  6 GB      128 GB   Blue Tide  5000 mAh
# 5  ₹19,948  6 GB      128 GB   Blue Tide  5000 mAh
# 6  ₹19,820  6 GB      128 GB  Black Dusk  5000 mAh
# 7  ₹19,989  6 GB      128 GB   Blue Tide  5000 mAh
#
#                         display    Primary Camera Secondary Camera
# 0  16.74 cm (6.59 inch) Display  64MP Rear Camera                -
# 1  16.74 cm (6.59 inch) Display  64MP Rear Camera                -
# 2  16.74 cm (6.59 inch) Display  64MP Rear Camera                -
# 3  16.74 cm (6.59 inch) Display  64MP Rear Camera                -
# 4  16.74 cm (6.59 inch) Display  64MP Rear Camera                -
# 5  16.74 cm (6.59 inch) Display  64MP Rear Camera                -
# 6  16.74 cm (6.59 inch) Display  64MP Rear Camera                -
# 7  16.74 cm (6.59 inch) Display  64MP Rear Camera                -

# %% [markdown]
# Question 5

# %%
driver.get("https://www.google.com/maps/@23.2390656,77.4275072,12z")

# %%
city =  input("Enter the city name: ")
# Out:
# Enter the city name: Delhi

# %%
search_tag = driver.find_element(By.CLASS_NAME,"tactile-searchbox-input")
search_tag.send_keys(city)

search_button = driver.find_element(By.CLASS_NAME,"mL3xi")
search_button.click()
time.sleep(3)

# %%
try:
    url_string = driver.current_url
    print("Url expected: ", url_string)
except:
    print("none")
# Out:
# Url expected:  https://www.google.com/maps/place/Delhi/@28.6437954,76.8130374,10z/data=!3m1!4b1!4m6!3m5!1s0x390cfd5b347eb62d:0x37205b715389640!8m2!3d28.7040592!4d77.1024902!16zL20vMDlmMDc

# %%
import re
lat_lng = re.findall(r'@(.*)data',url_string)

# %%
co_ordinates = lat_lng[0].split(',')

# %%
latitude = co_ordinates[0]
longitude = co_ordinates[1]

# %%
print ("latitude is  ",latitude,"Longitude is ",longitude)
# Out:
# latitude is   28.6437954 Longitude is  76.8130374

# %% [markdown]
# Question 6

# %%
driver.get("https://www.digit.in")

# %%
gaming = driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[5]/a')
gaming.click()

# %%
laptop = driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[5]/div[2]/div/div[2]/div/ul[3]/li[4]/a')
laptop.click()

# %%
title = []
review = []
para = []

# %%
try:
    title_tags = driver.find_elements(By.CLASS_NAME,"article_row")
    for i in title_tags:
        title.append(i.text.split('\n')[0])
except NoSuchElementException:
    title.append('-')

try:
    review_tags = driver.find_elements(By.CLASS_NAME,"review")
    for i in review_tags:
        review.append(i.get_attribute('href'))
except NoSuchElementException:
    review.append('-')
try:
    para_tags = driver.find_elements(By.CLASS_NAME,"article_row")
    for i in para_tags:
        para.append(i.text.split('\n')[2])
except NoSuchElementException:
    para.append('-')

# %%
print(len(title), len(review), len(para))
# Out:
# 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'title': title, 'review': review,'description': para})
df
# Out:
#                                  title  \
# 0    Best Asus Gaming Laptops in India
# 1  Best Gaming Laptops Under Rs 50,000
# 2       Best HP Gaming Laptop in India
# 3              Best Dell Gaming Laptop
# 4  Best Gaming Laptops Under Rs. 60000
# 5  Best Lenovo Gaming Laptops in India
# 6  Best Gaming Laptops under Rs. 40000
# 7     Best MSI Gaming Laptops in India
# 8    Best Gaming Laptops under ₹70,000
# 9     Best Gaming Laptops under 1 Lakh
#
#                                               review  \
# 0  https://www.digit.in/top-products/best-asus-ga...
# 1  https://www.digit.in/top-products/best-gaming-...
# 2  https://www.digit.in/top-products/best-hp-gami...
# 3  https://www.digit.in/top-products/best-dell-ga...
# 4  https://www.digit.in/top-products/best-gaming-...
# 5  https://www.digit.in/top-products/best-lenovo-...
# 6  https://www.digit.in/top-products/best-gaming-...
# 7  https://www.digit.in/top-products/best-msi-gam...
# 8  https://www.digit.in/top-products/gaming-lapto...
# 9  https://www.digit.in/top-products/best-gaming-...
#
#                                          description
# 0  <p>ASUS is a technical powerhouse and makes so...
# 1  If you’re in the market for a gaming laptop, t...
# 2  HP has been in the laptop market for a long ti...
# 3  Dell is a brand that is synonymous with gaming...
# 4  These days, buying a gaming laptop under 60000...
# 5  Lenovo is one of the biggest laptop manufactur...
# 6  Truth be told there aren’t any true gaming lap...
# 7  There are a lot of laptop OEMs in the market b...
# 8  Over the past few years, gaming laptops have s...
# 9  Just a few years ago it was hard to imagine th...

# %% [markdown]
# Question 7

# %%
driver.get("http://www.forbes.com/")

# %%
list = driver.find_element(By.XPATH,'//*[@id="globalHeaderMenu"]/div/div')
list.click()

# %%
header = driver.find_element(By.XPATH,'//*[@id="globalHeaderMenu"]/div/div[2]/ul/li[1]/div[1]')
header.click()

# %%
world = driver.find_element(By.XPATH,'//*[@id="globalHeaderMenu"]/div/div[2]/ul/li[1]/div[2]/div[3]/ul/li[1]/a')
world.click()

# %%
name = []
rank = []
country = []
net_worth = []
source = []
age = []
link = []

# %%
try:
    name_tags = driver.find_elements(By.CLASS_NAME,"personName")
    for i in name_tags[1:100]:
        name.append(i.text)
except NoSuchElementException:
    name.append('-')
try:
    rank_tags = driver.find_elements(By.CLASS_NAME,"rank")
    for i in rank_tags[1:100]:
        rank.append(i.text)
except NoSuchElementException:
    rank.append('-')
try:
    country_tags = driver.find_elements(By.CLASS_NAME,"countryOfCitizenship")
    for i in country_tags[1:100]:
        country.append(i.text)
except NoSuchElementException:
    country.append('-')

try:
    source_tags = driver.find_elements(By.CLASS_NAME,"source")
    for i in source_tags[1:100]:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')

try:
    net_tags = driver.find_elements(By.CLASS_NAME,"netWorth")
    for i in net_tags[1:100]:
        net_worth.append(i.text)
except NoSuchElementException:
    net_worth.append('-')
try:
    age_tags = driver.find_elements(By.CLASS_NAME,"age")
    for i in age_tags[1:100]:
        age.append(i.text)
except NoSuchElementException:
    age.append('-')

# %%
print(len(name), len(rank),len(age), len(country),len(net_worth), len(source))
# Out:
# 99 99 99 99 99 99

# %%
import pandas as pd
df = pd.DataFrame({'Name': name, 'rank': rank,'age': age, 'country': country, 'net worth': net_worth,'source': source})
df
# Out:
#                         Name rank age        country net worth  \
# 0                  Elon Musk   1.      United States    $219 B
# 1                 Jeff Bezos   2.      United States    $171 B
# 2   Bernard Arnault & family   3.             France    $158 B
# 3                 Bill Gates   4.      United States    $129 B
# 4             Warren Buffett   5.      United States    $118 B
# ..                       ...  ...  ..            ...       ...
# 94            Stefan Persson  94.             Sweden   $17.6 B
# 95               Steve Cohen  96.      United States   $17.4 B
# 96          Vladimir Potanin  97.             Russia   $17.3 B
# 97      Harold Hamm & family  98.      United States   $17.2 B
# 98              Sun Piaoyang  99.              China   $17.1 B
#
#                 source
# 0        Tesla, SpaceX
# 1               Amazon
# 2                 LVMH
# 3            Microsoft
# 4   Berkshire Hathaway
# ..                 ...
# 94                 H&M
# 95         hedge funds
# 96              metals
# 97           oil & gas
# 98     pharmaceuticals
#
# [99 rows x 6 columns]

# %% [markdown]
# question 8

# %%
video = input("Enter the youtube video link:  ")
# Out:
# Enter the youtube video link:  https://www.youtube.com/watch?v=OsU0CGZoV8E

# %%
driver.get(video)

# %%
comment = []
comment_time = []
comment_upvote = []

# %%
for _ in range(25):
    driver.execute_script("window.scrollBy(0,1000)")
    
    try:
        comment_tags = driver.find_elements(By.CLASS_NAME,'style-scope ytd-comment-renderer')
        for i in comment_tags[0:500]:
            comment.append(i.text.split('\n')[2])
    except NoSuchElementException:
        comment.append('-')

# %%
print(len(comment))
# Out:
# 500

# %%
for _ in range(25):
    driver.execute_script("window.scrollBy(0,1000)")
 
    try:
        time_tags = driver.find_elements(By.CLASS_NAME,'style-scope ytd-comment-renderer')
        for i in time_tags[0:500]:
            comment_time.append(i.text.split('\n')[1])
    except NoSuchElementException:
        comment_time.append('-')

# %%
print(len(comment_time))
# Out:
# 500

# %%
comment_upvote = []

# %%
for _ in range(25):
    driver.execute_script("window.scrollBy(0,1000)")
    try:
        upvote_tags = driver.find_elements(By.CLASS_NAME,'style-scope ytd-comment-action-buttons-renderer')
        for i in upvote_tags[0:500]:
            comment_upvote.append(i.text.split('\n')[0])
    except NoSuchElementException:
        comment_upvote.append('-')

# %%
print(len(comment_upvote))
# Out:
# 500

# %%
print(len(comment ), len(comment_time), len(comment_upvote))
# Out:
# 500 500 500

# %%
import pandas as pd
df = pd.DataFrame({'comment': comment, 'comment_time': comment_time, 'comment_upvote': comment_upvote})
df
# Out:
#                                                comment           comment_time  \
# 0    Congratulations to Rajmouli Sir and the entire...            1 month ago
# 1    You can see this movie was made with so much d...            1 month ago
# 2    4:10 genuinely makes me tear up. As a guy, we'...            12 days ago
# 3    If Ram Charan and NTR shows up and dance on st...            1 month ago
# 4    This scene is almost painful to watch when you...            12 days ago
# ..                                                 ...                    ...
# 495  I am so Proud to be a Telugu Person .. A telug...  17 hours ago (edited)
# 496      De los globos de Oro, para los premios Oscar.            1 month ago
# 497  Can we get them dancing at The Oscars? That wo...            1 month ago
# 498  I am from Kyiv, Ukraine, and I like that this ...            1 month ago
# 499  WOW!...finally indian music is making it out t...             5 days ago
#
#     comment_upvote
# 0             3.5K
# 1             1.1K
# 2              188
# 3              834
# 4              232
# ..             ...
# 495              4
# 496            170
# 497             84
# 498           2.3K
# 499             23
#
# [500 rows x 3 columns]

# %% [markdown]
# question 9

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("http://www.hostelworld.com/")

# %%
op = driver.find_element(By.XPATH,'//*[@id="search-field"]/div')
op.click()

# %%
loc = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')
loc.send_keys('London')

# %%
list = driver.find_element(By.XPATH,'//*[@id="predicted-search-results"]/li[2]/div')
list.click()

# %%
go = driver.find_element(By.XPATH,'//*[@id="search-button"]')
go.click()

# %%
name = []
distance = []
rating =[]
review =[]
private_price = []
prices = []
link = []
des = []

# %%
url = driver.find_elements(By.CLASS_NAME,"view-button")
for i in url:
    link.append(i.get_attribute("href"))

# %%
try:
    name_tags = driver.find_elements(By.CLASS_NAME,'property')
    for i in name_tags[1:]:
        name.append(i.text.split('\n')[0])
except NoSuchElementException:
    name.append('-')

# %%
try:
    distance_tags = driver.find_elements(By.CLASS_NAME,"description")
    for i in distance_tags:
        distance.append(i.text)
except NoSuchElementException:
    distance.append('-')

# %%
try:
    rating_tags = driver.find_elements(By.CLASS_NAME,"bottom-rating")
    for i in rating_tags:
        rating.append(i.text.split('\n')[0])
except NoSuchElementException:
    rating.append('-')

# %%
try:
    review_tags = driver.find_elements(By.CLASS_NAME,"reviews")
    for i in review_tags:
        review.append(i.text.split('\n')[0])
except NoSuchElementException:
    review.append('-')

# %%
try:
    price_tags = driver.find_elements(By.CLASS_NAME,"price-col")
    for i in price_tags:
        prices.append(i.text)
except NoSuchElementException:
    prices.append('-')

# %%
private = []
dorm = []
private = prices[::2]
dorm = prices[1::2]

# %%
try:
    des_tags = driver.find_elements(By.CLASS_NAME,"info")
    for i in des_tags[1:]:
        des.append(i.text.split('\n')[:3])
except NoSuchElementException:
    des.append('-')
print(len(des))
# Out:
# 30

# %%
fac = []
try:
    fac_tags = driver.find_elements(By.CLASS_NAME,"facilities-label.facilities")
    for i in fac_tags:
        fac.append(i.text)
except NoSuchElementException:
    fac.append('-')
print(len(fac))
# Out:
# 30

# %%
print(len(name), len(distance),len(rating),len(review),len(private),len(dorm),len(des),len(fac),len(link))
# Out:
# 30 30 30 30 30 30 30 30 30

# %%
import pandas as pd
df = pd.DataFrame({'Name': name, 'distance': distance,'rating': rating, 'review': review,'Description':des, 'Facilities':fac, 'Private':private,'Dorm':dorm, 'Link':link})
df
# Out:
#                                        Name                         distance  \
# 0                  St Christopher's Village  Hostel - 1.8km from city centre
# 1                   Hostel One Notting Hill  Hostel - 5.5km from city centre
# 2                          Generator London    Hostel - 3km from city centre
# 3         Safestay London Elephant & Castle  Hostel - 1.7km from city centre
# 4               Smart Russell Square Hostel  Hostel - 2.6km from city centre
# 5                      Urbany Hostel London  Hostel - 5.4km from city centre
# 6   Safestay London Kensington Holland Park  Hostel - 5.8km from city centre
# 7                        No.8 Seven Sisters    Hostel - 9km from city centre
# 8              St Christopher's Hammersmith  Hostel - 7.5km from city centre
# 9      St Christopher's Inn - London Bridge  Hostel - 1.8km from city centre
# 10  St Christopher's Inn - Liverpool Street  Hostel - 3.2km from city centre
# 11              Smart Hyde Park View Hostel  Hostel - 4.8km from city centre
# 12     PubLove @ The Steam Engine, Waterloo  Hostel - 0.5km from city centre
# 13               St Christopher's Greenwich  Hostel - 7.6km from city centre
# 14                               Park Villa  Hostel - 6.3km from city centre
# 15                 Kensal Green Backpackers  Hostel - 8.2km from city centre
# 16                  Saint James Backpackers  Hostel - 5.5km from city centre
# 17           PubLove @ The Crown, Battersea  Hostel - 4.7km from city centre
# 18      PubLove @ The White Ferry, Victoria  Hostel - 2.4km from city centre
# 19                        Bell House Hostel  Hostel - 4.2km from city centre
# 20                            Selina Camden  Hostel - 5.5km from city centre
# 21                            Elmwood Hotel   Hotel - 3.2km from city centre
# 22               PubLove @ The Rose & Crown  Hostel - 1.6km from city centre
# 23      PubLove @ The Green Man, Paddington  Hostel - 4.3km from city centre
# 24                   London Waterloo Hostel  Hostel - 0.7km from city centre
# 25       PubLove @ The Exmouth Arms, Euston  Hostel - 3.4km from city centre
# 26                          Hostelle London  Hostel - 5.1km from city centre
# 27                   TLK Apartments & Hotel  Hotel - 19.9km from city centre
# 28                                Kip Hotel   Hotel - 6.8km from city centre
# 29                      The W14 Hotel & Bar   Hotel - 6.5km from city centre
#
#        rating               review  \
# 0         7.8  11982 Total Reviews
# 1         9.4   1817 Total Reviews
# 2         7.4   7387 Total Reviews
# 3         7.3   4861 Total Reviews
# 4         7.4   9929 Total Reviews
# 5         9.1    687 Total Reviews
# 6         7.2   1452 Total Reviews
# 7         5.6   3971 Total Reviews
# 8         7.6   4207 Total Reviews
# 9         7.4   3463 Total Reviews
# 10        7.9    482 Total Reviews
# 11        8.0   4678 Total Reviews
# 12        8.0    376 Total Reviews
# 13        7.0   3318 Total Reviews
# 14        9.0    886 Total Reviews
# 15        5.1   3702 Total Reviews
# 16        7.6   1869 Total Reviews
# 17        7.3    294 Total Reviews
# 18        7.7    321 Total Reviews
# 19        6.8     41 Total Reviews
# 20        8.8     46 Total Reviews
# 21        7.7    126 Total Reviews
# 22        7.3    174 Total Reviews
# 23        6.8    442 Total Reviews
# 24        4.5   2527 Total Reviews
# 25        6.3   1071 Total Reviews
# 26        8.9      4 Total Reviews
# 27  No Rating      0 Total Reviews
# 28        7.7     55 Total Reviews
# 29        8.4    282 Total Reviews
#
#                                           Description  \
# 0   [Perfect Location, Marvellous Staff, Excellent...
# 1   [Perfect Location, Superb Staff, Fantastic Cle...
# 2   [Perfect Location, Marvellous Staff, Awesome C...
# 3   [Wonderful Location, Marvellous Staff, Excelle...
# 4   [Perfect Location, Marvellous Staff, Awesome C...
# 5   [Perfect Location, Superb Staff, Fantastic Cle...
# 6   [Perfect Location, Marvellous Staff, Awesome C...
# 7                      [Brilliant Staff, 5.6, Rating]
# 8   [Perfect Location, Superb Staff, Excellent Cle...
# 9   [Perfect Location, Marvellous Staff, Awesome C...
# 10  [Perfect Location, Superb Staff, Excellent Cle...
# 11  [Perfect Location, Superb Staff, Excellent Cle...
# 12  [Perfect Location, Superb Staff, Awesome Clean...
# 13  [Wonderful Location, Marvellous Staff, Awesome...
# 14  [Perfect Location, Superb Staff, Fantastic Cle...
# 15                      [Great Location, 5.1, Rating]
# 16  [Perfect Location, Superb Staff, Awesome Clean...
# 17  [Wonderful Location, Marvellous Staff, Awesome...
# 18  [Perfect Location, Superb Staff, Awesome Clean...
# 19              [Perfect Location, Superb Staff, 6.8]
# 20  [Perfect Location, Superb Staff, Fantastic Cle...
# 21  [Perfect Location, Superb Staff, Awesome Clean...
# 22  [Perfect Location, Marvellous Staff, Awesome C...
# 23  [Wonderful Location, Superb Staff, Good Cleanl...
# 24                      [Great Location, 4.5, Rating]
# 25         [Wonderful Location, Brilliant Staff, 6.3]
# 26  [Perfect Location, Superb Staff, Fantastic Cle...
# 27                       [No Rating, 0 Total Reviews]
# 28              [Perfect Location, Superb Staff, 7.7]
# 29  [Great Location, Marvellous Staff, Fantastic C...
#
#                                            Facilities                 Private  \
# 0     Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 1                                           Free WiFi  Privates From\nRs19597
# 2     Free WiFi\nFollows Covid-19 sanitation guidance  Privates From\nRs12545
# 3     Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 4     Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 5     Free WiFi\nFollows Covid-19 sanitation guidance  Privates From\nRs17968
# 6                                           Free WiFi   No Privates Available
# 7     Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 8     Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 9     Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 10    Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 11    Free WiFi\nFollows Covid-19 sanitation guidance  Privates From\nRs28724
# 12                                          Free WiFi   No Privates Available
# 13    Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 14    Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 15               Follows Covid-19 sanitation guidance   No Privates Available
# 16  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...  Privates From\nRs20603
# 17                                          Free WiFi   No Privates Available
# 18                                          Free WiFi   No Privates Available
# 19                                          Free WiFi   No Privates Available
# 20                                          Free WiFi  Privates From\nRs26520
# 21                                                     Privates From\nRs16975
# 22                                          Free WiFi   No Privates Available
# 23                                          Free WiFi  Privates From\nRs29379
# 24    Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 25                                          Free WiFi   No Privates Available
# 26    Free WiFi\nFollows Covid-19 sanitation guidance   No Privates Available
# 27                                          Free WiFi  Privates From\nRs10039
# 28                                          Free WiFi  Privates From\nRs10838
# 29                          Free WiFi\nFree Breakfast  Privates From\nRs15016
#
#                             Dorm  \
# 0    Dorms From\nRs3250.6 Rs2926
# 1             Dorms From\nRs6556
# 2             Dorms From\nRs3702
# 3             Dorms From\nRs3555
# 4             Dorms From\nRs3943
# 5             Dorms From\nRs5973
# 6             Dorms From\nRs3878
# 7             Dorms From\nRs2166
# 8   Dorms From\nRs3322.78 Rs2991
# 9   Dorms From\nRs4301.37 Rs3871
# 10  Dorms From\nRs4228.46 Rs3806
# 11            No Dorms Available
# 12            Dorms From\nRs4733
# 13  Dorms From\nRs2942.29 Rs2648
# 14            Dorms From\nRs5063
# 15            Dorms From\nRs2840
# 16            Dorms From\nRs6006
# 17            Dorms From\nRs4929
# 18            Dorms From\nRs6333
# 19            Dorms From\nRs3362
# 20            No Dorms Available
# 21            No Dorms Available
# 22            Dorms From\nRs5713
# 23            Dorms From\nRs4799
# 24            Dorms From\nRs5304
# 25            Dorms From\nRs6920
# 26            Dorms From\nRs4048
# 27            No Dorms Available
# 28            No Dorms Available
# 29            No Dorms Available
#
#                                                  Link
# 0   https://www.hostelworld.com/pwa/hosteldetails....
# 1   https://www.hostelworld.com/pwa/hosteldetails....
# 2   https://www.hostelworld.com/pwa/hosteldetails....
# 3   https://www.hostelworld.com/pwa/hosteldetails....
# 4   https://www.hostelworld.com/pwa/hosteldetails....
# 5   https://www.hostelworld.com/pwa/hosteldetails....
# 6   https://www.hostelworld.com/pwa/hosteldetails....
# 7   https://www.hostelworld.com/pwa/hosteldetails....
# 8   https://www.hostelworld.com/pwa/hosteldetails....
# 9   https://www.hostelworld.com/pwa/hosteldetails....
# 10  https://www.hostelworld.com/pwa/hosteldetails....
# 11  https://www.hostelworld.com/pwa/hosteldetails....
# 12  https://www.hostelworld.com/pwa/hosteldetails....
# 13  https://www.hostelworld.com/pwa/hosteldetails....
# 14  https://www.hostelworld.com/pwa/hosteldetails....
# 15  https://www.hostelworld.com/pwa/hosteldetails....
# 16  https://www.hostelworld.com/pwa/hosteldetails....
# 17  https://www.hostelworld.com/pwa/hosteldetails....
# 18  https://www.hostelworld.com/pwa/hosteldetails....
# 19  https://www.hostelworld.com/pwa/hosteldetails....
# 20  https://www.hostelworld.com/pwa/hosteldetails....
# 21  https://www.hostelworld.com/pwa/hosteldetails....
# 22  https://www.hostelworld.com/pwa/hosteldetails....
# 23  https://www.hostelworld.com/pwa/hosteldetails....
# 24  https://www.hostelworld.com/pwa/hosteldetails....
# 25  https://www.hostelworld.com/pwa/hosteldetails....
# 26  https://www.hostelworld.com/pwa/hosteldetails....
# 27  https://www.hostelworld.com/pwa/hosteldetails....
# 28  https://www.hostelworld.com/pwa/hosteldetails....
# 29  https://www.hostelworld.com/pwa/hosteldetails....
