# %%
pip install selenium
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: selenium in c:\users\yashika\anaconda3\lib\site-packages (4.8.2)
# ...

# %%
import selenium

import pandas as pd

from selenium import webdriver

import warnings

warnings.filterwarnings('ignore')

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

from selenium.webdriver.common.by import By

import time

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/input")
location.send_keys('Banglore')

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[:10]:
    company = i.text
    company_name.append(company)

experience_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[:10]:
    exp = i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title, 'Location':job_location, 'company_name': company_name, 'Experience':experience_required})
df
# Out:
#                                                Title  \
# 0                                  Tech Data Analyst
# 1                                       Data Analyst
# 2  K12 Techno Services - Data Analyst - IIM/ISB/M...
# 3    Hiring For Data Analyst-Bangalore-Contract role
# 4                                       Data Analyst
# 5                                       Data Analyst
# 6                                       Data Analyst
# 7                              Graduate Data Analyst
# 8                                       Data Analyst
# 9                               Walmart Data Analyst
#
#                                             Location  \
# 0     Hybrid - Gurgaon/Gurugram, Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                       Kolkata, Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# Question 2

# %%
driver.get("https://www.naukri.com/")

designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Banglore')

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title = []
job_location = []
company_name = []

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[:10]:
    company = i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title, 'Location':job_location, 'company_name': company_name, 'Experience':experience_required})
df
# Out:
#                                  Title  \
# 0                Senior data scientist
# 1                   Data Scientist_NLP
# 2                       Data Scientist
# 3              Data Science Specialist
# 4     Analystics & Modeling Specialist
# 5                       Data Scientist
# 6                    Lead ML Scientist
# 7     Lead Machine Learning Specialist
# 8  Senior Data Scientist-New Frontiers
# 9                 Staff Data Scientist
#
#                                             Location       company_name  \
# 0  Mumbai, Pune, Chennai, Gurgaon/Gurugram, Banga...   Fractal Protocol
# 1  Mumbai, Pune, Chennai, Gurgaon/Gurugram, Banga...   Fractal Protocol
# 2  Mumbai, Pune, Chennai, Gurgaon/Gurugram, Banga...   Fractal Protocol
# 3  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...          Accenture
# 4  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...          Accenture
# 5  Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...          Cognizant
# ...

# %% [markdown]
# Question 3

# %%
driver = webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.naukri.com/")

designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
salary = driver.find_element(By.XPATH,'//*[@id="root"]/div[4]/div/div/section[1]/div[2]/div[2]/div[2]/div[2]/label/i')
salary.click()

# %%
location = driver.find_element(By.XPATH,'//*[@id="root"]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[3]/label/i')
location.click()

# %%
job_title = []
job_location = []
company_name = []

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[:10]:
    company = i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title, 'Location':job_location, 'company_name': company_name})
df
# Out:
#                                       Title  \
# 0               Data Scientist data Analyst
# 1         Data Scientist - Engine Algorithm
# 2                      Analyst-Data Science
# 3                      Analyst-Data Science
# 4                            Data Scientist
# 5                            Data Scientist
# 6       Associate Data Scientist - ML & NLP
# 7  Data Scientist || Walk-In || 5th-6th Jan
# 8       Research Scientist - Bioinformatics
# 9                            Data Scientist
#
#                                             Location  \
# 0  Delhi / NCR, Kolkata, Hyderabad/Secunderabad, ...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2                                   Gurgaon/Gurugram
# 3                                   Gurgaon/Gurugram
# 4  Delhi / NCR, Noida(Sector-136 Noida), Ghaziaba...
# 5                                   Gurgaon/Gurugram
# 6                                   Gurgaon/Gurugram
# ...

# %% [markdown]
# Question 4

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

products = driver.find_element(By.CLASS_NAME,"_3704LK")
products.send_keys('sunglasses')

# %%
time.sleep(10)
search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand = []
product_des = []
price = []
offer = []

# %%
start = 0
end = 3
for page in range(start,end):
    brand_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags[0:100]:
        brand.append(i.text)

    product_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags[0:100]:
        product_des.append(i.text)

    price_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags[0:100]:
        price.append(i.text)
        
    offer_tags = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in offer_tags[0:100]:
        offer.append(i.text)

    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(10)

# %%
print(len(brand))
# Out:
# 120

# %%
print(len(brand), len(product_des),len(price),len(offer))
# Out:
# 120 120 120 120

# %%
import pandas as pd
df = pd.DataFrame({'BRAND':brand, 'Product description': product_des,'Price': price, 'offer': offer})
df.head(100)
# Out:
#              BRAND                                Product description   Price  \
# 0           AISLIN  Toughened Glass Lens, UV Protection Aviator, W...    ₹845
# 1   ROZZETTA CRAFT              UV Protection Aviator Sunglasses (62)    ₹616
# 2            NuVew   UV Protection, Mirrored Wayfarer Sunglasses (58)     ₹99
# 3            NuVew   UV Protection, Mirrored Wayfarer Sunglasses (57)     ₹99
# 4            NuVew   UV Protection, Mirrored Wayfarer Sunglasses (58)     ₹99
# ..             ...                                                ...     ...
# 95     Eyewearlabs     Polarized, UV Protection Round Sunglasses (47)  ₹1,698
# 96       Elligator             UV Protection Wayfarer Sunglasses (53)    ₹149
# 97          PIRASO       UV Protection Aviator Sunglasses (Free Size)    ₹268
# 98        Fastrack       UV Protection Aviator Sunglasses (Free Size)    ₹579
# 99  ROZZETTA CRAFT              UV Protection Aviator Sunglasses (62)    ₹585
#
#       offer
# 0   77% off
# ...

# %% [markdown]
# Question 5

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR")

# %%
rating = []
review_summary = []
full_summary = []

# %%
start = 0
end = 10
for page in range(start,end):
    rating_tags = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tags[0:100]:
        rating.append(i.text)
    
    review_tags = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review_tags[0:100]:
        review_summary.append(i.text)
    
    full_tags = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_tags[0:100]:
        full_summary.append(i.text)


    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(10)

# %%
print(len(rating),len(review_summary),len(full_summary))
# Out:
# 100 100 100

# %%
import pandas as pd
df = pd.DataFrame({'Rating':rating, 'Review': review_summary,'Full Review': full_summary})
df
# Out:
#    Rating               Review  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      4      Value-for-money
# 96      5     Perfect product!
# 97      5   Highly recommended
# 98      5     Perfect product!
# 99      5   Highly recommended
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Just got this iphone 11\nAnd it is most powerf...
# 96  Value for money❤️❤️\nIts awesome mobile phone ...
# 97  iphone 11 is a very good phone to buy only if ...
# ...

# %% [markdown]
# Question 6

# %%
driver.get("https://www.flipkart.com/")

products = driver.find_element(By.CLASS_NAME,"_3704LK")
products.send_keys('sneakers')

time.sleep(10)
search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand = []
product_des = []
price = []

# %%
start = 0
end = 3
for page in range(start,end):
    brand_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags[0:100]:
        brand.append(i.text)

    product_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags[0:100]:
        product_des.append(i.text)

    price_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags[0:100]:
        price.append(i.text)

    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(30)

# %%
print(len(brand), len(product_des),len(price))
# Out:
# 120 120 120

# %%
import pandas as pd
df = pd.DataFrame({'BRAND':brand,'Price': price})
df.head(100)
# Out:
#           BRAND   Price
# 0        BRUTON    ₹249
# 1           SFR    ₹279
# 2         BIRDE    ₹299
# 3           SFR    ₹249
# 4         Sparx    ₹524
# ..          ...     ...
# 95        BIRDE    ₹499
# 96  Asian Shoes    ₹449
# 97        BIRDE    ₹449
# 98         PUMA  ₹1,959
# 99         PUMA  ₹1,593
#
# [100 rows x 2 columns]

# %% [markdown]
# question 7

# %%
driver.get("https://www.amazon.in/")

# %%
search = driver.find_element(By.XPATH,'//*[@id="twotabsearchtextbox"]')
search.send_keys('Laptop')

time.sleep(5)
search = driver.find_element(By.XPATH,'//*[@id="nav-search-submit-button"]')
search.click()

# %%
cpu_filter = driver.find_element(By.XPATH,'//*[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/div/label/i')
cpu_filter.click()

# %%
title = []
ratings = []
price = []
title_tags =[]
url = []

# %%
url = driver.find_elements(By.CLASS_NAME,"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal")
for i in url[0:10]:
    url.append(i.get_attribute("href"))

# %% [markdown]
# question 8

# %%
driver.get("https://www.azquotes.com/")

# %%
search = driver.find_element(By.XPATH,'//*[@id="menu"]/div/div[3]/ul/li[5]/a')
search.click()

# %%
quote = []
author = []
qtype = []

# %%
quote_tags = driver.find_elements(By.CLASS_NAME,"title")
for i in quote_tags[1:101]:
    quote.append(i.text)
        
author_tags = driver.find_elements(By.CLASS_NAME,"author")
for i in author_tags:
    author.append(i.text)

q_tags = driver.find_elements(By.CLASS_NAME,"tags")
for i in q_tags:
    qtype.append(i.text)

# %%
print(len(qtype))
# Out:
# 1000

# %%
print(len(quote), len(author), len(qtype))
# Out:
# 100 100 100

# %%
import pandas as pd
df = pd.DataFrame({'Author':author,'quotes': quote, 'qtype':qtype})
df
# Out:
#                     Author                                             quotes  \
# 0           Amelia Earhart  Courage is the price that life exacts for gran...
# 1         Ludwig von Mises  The worst evils which mankind has ever had to ...
# 2   Elizabeth Cady Stanton  The moment we begin to fear the opinions of ot...
# 3           Benjamin Spock  Trust yourself, you know more than you think y...
# 4        Charles Kettering  High achievement always takes place in the fra...
# ..                     ...                                                ...
# 95        Sydney J. Harris  Regret for the things we did can be tempered b...
# 96      Hunter S. Thompson  America... just a nation of two hundred millio...
# 97                Jim Rohn  For every disciplined effort there is a multip...
# 98                Ram Dass  The spiritual journey is individual, highly pe...
# 99                Plutarch  The mind is not a vessel to be filled but a fi...
#
# ...

# %% [markdown]
# question 9

# %%
driver.get("http://www.jagranjosh.com/")

# %%
gk = driver.find_element(By.XPATH,'//*[@id="1540978020504"]/div[1]/header/div[3]/ul/li[9]/a')
gk.click()

# %%
p = driver.find_element(By.XPATH,'//*[@id="1609937029749"]/div/ul/li[2]/a')
p.click()

# %%
pm = driver.find_element(By.XPATH,'//*[@id="popluarGK"]/ul/li[2]/a')
pm.click()

# %%
pm_name =[]

# %%
row = []
col = []
elemt = []

# %%
r = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr')
print(len(r))
# Out:
# 19

# %%
c = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr[1]/th')
print(len(c))
# Out:
# 5

# %%
el = []
el_tags = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[3]/table/tbody/tr[2]/td[1]/p/strong')
for i in el_tags:
    el.append(i.text)

# %%
el
# Out:
# ['1.']

# %%
r = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr')
print(len(r))
c = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr[1]/th')
print(len(c))
i = 1
j = 1
for indx,val in enumerate(r):
    while i < 18:
        for idx,val in enumerate(c):    
            j=1
            i+=1
            while j < 6 :                  
                d=driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr['+str(i)+']/td['+str(j)+']/p')
                for k in d:
                    row.append(k.text)
                j+=1
# Out:
# 19
# 5

# %%
r = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr')
print(len(r))
c = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr[1]/th')
print(len(c))
i = 1
j = 0
for indx,val in enumerate(c):
    while j < 6:
        print("j is",j)
        i=1
        j+=1
        for idx,val in enumerate(r):    
            while i < 20 :                  
                d=driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[4]/table/tbody/tr['+str(i)+']/td['+str(j)+']/p')
                for k in d:
                    row.append(k.text) 
                i+=1
# Out:
# 19
# 5
# j is 0
# j is 1
# j is 2
# j is 3
# j is 4
# j is 5

# %%
print(len(row))
# Out:
# 107

# %%
t = row[54:72]
t2 = row[72:89]
k =[]
n = 54
while n<89:
    t3 = row[n]+row[n+1]
    n+=2
    print(t3)
    k.append(t3)
print(len(k))
# Out:
# 15 August 1947 to 27 May 196416 years, 286 days
# 27 May 1964 to 9 June 1964,13 days
# 9 June 1964 to 11 January 19661 year, 216 days
# 11 January 1966 to 24 January 196613 days
# 24 January 1966 to 24 March 197711 years, 59 days
# 24 March 1977 to  28 July 1979 2 year, 126 days
# 28 July 1979 to 14 January 1980170 days
# 14 January 1980 to 31 October 19844 years, 291 days
# 31 October 1984 to 2 December 19895 years, 32 days
# 2 December 1989 to 10 November 1990343 days
# 10 November 1990 to 21 June 1991223 days
# 21 June 1991 to 16 May 19964 years, 330 days
# 16 May 1996 to 1 June 199616 days
# 1 June 1996 to 21 April 1997324 days
# 21 April 1997 to 19 March 1998 332 days
# 19 March 1998 to 22 May 2004 6 years, 64 days
# 22 May 2004 to 26 May 2014   10 years, 4 days
# 26 May 2014 - PresentThe first prime minister of India and the longest-serving PM of India, the first to die in office.
# 18

# %%
import pandas as pd
df = pd.DataFrame({'s.no':row[0:18],'name': row[18:36], 'Born-Dead': row[36:54], 'term':k, 'Remark': row[89:107]})
df
# Out:
#    s.no                         name     Born-Dead  \
# 0    1.            Jawahar Lal Nehru   (1889–1964)
# 1    2.    Gulzarilal Nanda (Acting)   (1898-1998)
# 2    3.          Lal Bahadur Shastri   (1904–1966)
# 3   4.   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4    5.                Indira Gandhi   (1917–1984)
# 5    6.                Morarji Desai   (1896–1995)
# 6    7.                 Charan Singh   (1902–1987)
# 7    8.                Indira Gandhi   (1917–1984)
# 8    9.                 Rajiv Gandhi   (1944–1991)
# 9   10.                  V. P. Singh   (1931–2008)
# 10  11.              Chandra Shekhar   (1927–2007)
# 11  12.          P. V. Narasimha Rao   (1921–2004)
# 12  13.         Atal Bihari Vajpayee  (1924- 2018)
# 13  14.             H. D. Deve Gowda   (born 1933)
# 14  15.           Inder Kumar Gujral   (1919–2012)
# 15  16.         Atal Bihari Vajpayee   (1924-2018)
# 16  17.               Manmohan Singh   (born 1932)
# ...

# %%
name_tags = driver.find_elements(By.XPATH,('//*[@class="table-box"]'))
for i in name_tags:
    pm_name.append(i.text.split('\n'))

# %%
pm_name
# Out:
# [['S.N.',
#   'Name',
#   'Born-Dead',
#   'Term of office',
#   'Remark',
#   '1.',
#   'Jawahar Lal Nehru',
#   '(1889–1964)',
#   '15 August 1947 to 27 May 1964',
#   '16 years, 286 days',
#   'The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#   '2.',
#   'Gulzarilal Nanda (Acting)',
#   '(1898-1998)',
#   '27 May 1964 to 9 June 1964,',
#   '13 days',
#   'First acting PM of India',
#   '3.',
#   'Lal Bahadur Shastri',
#   '(1904–1966)',
#   '9 June 1964 to 11 January 1966',
#   '1 year, 216 days',
#   "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#   '4. ',
#   'Gulzari Lal Nanda  (Acting)',
#   '(1898-1998)',
#   '11 January 1966 to 24 January 1966',
#   '13 days',
#   '-',
#   '5.',
#   'Indira Gandhi',
#   '(1917–1984)',
#   '24 January 1966 to 24 March 1977',
#   '11 years, 59 days',
#   'First female Prime Minister of India',
#   '6.',
#   'Morarji Desai',
#   '(1896–1995)',
# ...

# %%
life_tags = driver.find_elements(By.CLASS_NAME,"author")

    for i in life_tags:
        life.append(i.text)
term_tags = driver.find_elements(By.CLASS_NAME,"author")

    for i in term_tags:
        term.append(i.text)
remark_tags = driver.find_elements(By.CLASS_NAME,"author")
    for i in remark_tags:
        remark.append(i.text)

# %% [markdown]
# question 10

# %%
driver.get("https://www.motor1.com/")

# %%
gk = driver.find_element(By.XPATH,'//*[@id="page_index_index_index"]/div[2]/div/div/div[1]/div')
gk.click()

# %%
p = driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[5]/a')
p.click()

# %%
a = driver.find_element(By.XPATH,'//*[@id="page_index_articles_browse"]/div[7]/div/div[1]/div[1]/div[4]/div/div[1]/h3/a')
a.click()

# %%
name = []
price = []
list =[]

# %%
name_tags = driver.find_elements(By.CLASS_NAME,"subheader")
for i in name_tags[:48]:
    name.append(i.text)

# %%
price_tags = driver.find_elements(By.XPATH,"//strong[contains(text(),'Price: $')]")
for i in price_tags:
    price.append(i.text)

# %%
print(len(price),len(name))
# Out:
# 48 48

# %%
import pandas as pd
df = pd.DataFrame({'name': name,'price':price,})
df
# Out:
#                                name                        price
# 0                     De Tomaso P72          Price: $1.3 Million
# 1                 Ferrari LaFerrari          Price: $1.4 Million
# 2                     Pagani Huayra          Price: $1.4 Million
# 3                      McLaren Elva          Price: $1.7 Million
# 4                       Czinger 21C          Price: $1.7 Million
# 5                     Ferrari Monza          Price: $1.7 Million
# 6                Gordon Murray T.33          Price: $1.7 Million
# 7                 Koenigsegg Gemera          Price: $1.7 Million
# 8                       Zenvo TSR-S          Price: $1.7 Million
# 9                Hennessey Venom F5          Price: $1.8 Million
# 10                  Bentley Bacalar          Price: $1.9 Million
# 11    Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 12           Bentley Mulliner Batur          Price: $2.0 Million
# ...
